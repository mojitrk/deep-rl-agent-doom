# %%
#PREREQS

# %pip install vizdoom
# %pip install gymnasium

# %pip install tqdm
# %pip install scikit-image

# %pip install sample-factory
# Out:
# Requirement already satisfied: vizdoom in ./.conda/lib/python3.11/site-packages (1.2.3)
# Requirement already satisfied: numpy in ./.conda/lib/python3.11/site-packages (from vizdoom) (2.0.0)
# Requirement already satisfied: gymnasium>=0.28.0 in ./.conda/lib/python3.11/site-packages (from vizdoom) (0.29.1)
# Requirement already satisfied: pygame>=2.1.3 in ./.conda/lib/python3.11/site-packages (from vizdoom) (2.6.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./.conda/lib/python3.11/site-packages (from gymnasium>=0.28.0->vizdoom) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in ./.conda/lib/python3.11/site-packages (from gymnasium>=0.28.0->vizdoom) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in ./.conda/lib/python3.11/site-packages (from gymnasium>=0.28.0->vizdoom) (0.0.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: gymnasium in ./.conda/lib/python3.11/site-packages (0.29.1)
# Requirement already satisfied: numpy>=1.21.0 in ./.conda/lib/python3.11/site-packages (from gymnasium) (2.0.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./.conda/lib/python3.11/site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in ./.conda/lib/python3.11/site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in ./.conda/lib/python3.11/site-packages (from gymnasium) (0.0.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tqdm in ./.conda/lib/python3.11/site-packages (4.66.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: scikit-image in ./.conda/lib/python3.11/site-packages (0.24.0)
# Requirement already satisfied: numpy>=1.23 in ./.conda/lib/python3.11/site-packages (from scikit-image) (2.0.0)
# Requirement already satisfied: scipy>=1.9 in ./.conda/lib/python3.11/site-packages (from scikit-image) (1.14.0)
# Requirement already satisfied: networkx>=2.8 in ./.conda/lib/python3.11/site-packages (from scikit-image) (3.3)
# Requirement already satisfied: pillow>=9.1 in ./.conda/lib/python3.11/site-packages (from scikit-image) (10.3.0)
# Requirement already satisfied: imageio>=2.33 in ./.conda/lib/python3.11/site-packages (from scikit-image) (2.34.2)
# Requirement already satisfied: tifffile>=2022.8.12 in ./.conda/lib/python3.11/site-packages (from scikit-image) (2024.6.18)
# Requirement already satisfied: packaging>=21 in ./.conda/lib/python3.11/site-packages (from scikit-image) (24.1)
# Requirement already satisfied: lazy-loader>=0.4 in ./.conda/lib/python3.11/site-packages (from scikit-image) (0.4)
# Note: you may need to restart the kernel to use updated packages.
# Collecting sample-factory
#   Using cached sample_factory-2.1.1-py3-none-any.whl.metadata (12 kB)
# Collecting numpy<2.0,>=1.18.1 (from sample-factory)
#   Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Requirement already satisfied: torch!=1.13.0,<3.0,>=1.9 in ./.conda/lib/python3.11/site-packages (from sample-factory) (2.3.1)
# Requirement already satisfied: gymnasium<1.0,>=0.27 in ./.conda/lib/python3.11/site-packages (from sample-factory) (0.29.1)
# Collecting pyglet (from sample-factory)
#   Using cached pyglet-2.0.15-py3-none-any.whl.metadata (7.8 kB)
# Collecting tensorboard>=1.15.0 (from sample-factory)
#   Using cached tensorboard-2.17.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting tensorboardx>=2.0 (from sample-factory)
#   Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: psutil>=5.7.0 in ./.conda/lib/python3.11/site-packages (from sample-factory) (6.0.0)
# Collecting threadpoolctl>=2.0.0 (from sample-factory)
#   Using cached threadpoolctl-3.5.0-py3-none-any.whl.metadata (13 kB)
# Collecting colorlog (from sample-factory)
#   Using cached colorlog-6.8.2-py3-none-any.whl.metadata (10 kB)
# Collecting signal-slot-mp<2.0,>=1.0.3 (from sample-factory)
#   Using cached signal_slot_mp-1.0.5-py3-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: filelock in ./.conda/lib/python3.11/site-packages (from sample-factory) (3.15.4)
# Collecting opencv-python (from sample-factory)
#   Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Collecting wandb>=0.12.9 (from sample-factory)
#   Using cached wandb-0.17.3-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Collecting huggingface-hub<1.0,>=0.10.0 (from sample-factory)
#   Using cached huggingface_hub-0.23.4-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in ./.conda/lib/python3.11/site-packages (from gymnasium<1.0,>=0.27->sample-factory) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in ./.conda/lib/python3.11/site-packages (from gymnasium<1.0,>=0.27->sample-factory) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in ./.conda/lib/python3.11/site-packages (from gymnasium<1.0,>=0.27->sample-factory) (0.0.4)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in ./.conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory) (24.1)
# Collecting pyyaml>=5.1 (from huggingface-hub<1.0,>=0.10.0->sample-factory)
#   Using cached PyYAML-6.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting requests (from huggingface-hub<1.0,>=0.10.0->sample-factory)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: tqdm>=4.42.1 in ./.conda/lib/python3.11/site-packages (from huggingface-hub<1.0,>=0.10.0->sample-factory) (4.66.4)
# Collecting faster-fifo<2.0,>=1.4.4 (from signal-slot-mp<2.0,>=1.0.3->sample-factory)
#   Using cached faster_fifo-1.4.7.tar.gz (112 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting absl-py>=0.4 (from tensorboard>=1.15.0->sample-factory)
#   Using cached absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=1.15.0->sample-factory)
#   Using cached grpcio-1.64.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=1.15.0->sample-factory)
#   Using cached Markdown-3.6-py3-none-any.whl.metadata (7.0 kB)
# Collecting protobuf!=4.24.0,<5.0.0,>=3.19.6 (from tensorboard>=1.15.0->sample-factory)
#   Using cached protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl.metadata (541 bytes)
# Requirement already satisfied: setuptools>=41.0.0 in ./.conda/lib/python3.11/site-packages (from tensorboard>=1.15.0->sample-factory) (69.5.1)
# Requirement already satisfied: six>1.9 in ./.conda/lib/python3.11/site-packages (from tensorboard>=1.15.0->sample-factory) (1.16.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=1.15.0->sample-factory)
#   Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=1.15.0->sample-factory)
#   Using cached werkzeug-3.0.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: sympy in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (1.12.1)
# Requirement already satisfied: networkx in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (3.3)
# Requirement already satisfied: jinja2 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (3.1.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (12.1.105)
# Requirement already satisfied: triton==2.3.1 in ./.conda/lib/python3.11/site-packages (from torch!=1.13.0,<3.0,>=1.9->sample-factory) (2.3.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.conda/lib/python3.11/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch!=1.13.0,<3.0,>=1.9->sample-factory) (12.5.40)
# Collecting click!=8.0.0,>=7.1 (from wandb>=0.12.9->sample-factory)
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting docker-pycreds>=0.4.0 (from wandb>=0.12.9->sample-factory)
#   Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl.metadata (1.8 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb>=0.12.9->sample-factory)
#   Using cached GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: platformdirs in ./.conda/lib/python3.11/site-packages (from wandb>=0.12.9->sample-factory) (4.2.2)
# Collecting sentry-sdk>=1.0.0 (from wandb>=0.12.9->sample-factory)
#   Using cached sentry_sdk-2.7.1-py2.py3-none-any.whl.metadata (14 kB)
# Collecting setproctitle (from wandb>=0.12.9->sample-factory)
#   Using cached setproctitle-1.3.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.9 kB)
# Collecting cython>=0.29 (from faster-fifo<2.0,>=1.4.4->signal-slot-mp<2.0,>=1.0.3->sample-factory)
#   Using cached Cython-3.0.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.2 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb>=0.12.9->sample-factory)
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Collecting charset-normalizer<4,>=2 (from requests->huggingface-hub<1.0,>=0.10.0->sample-factory)
#   Using cached charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (33 kB)
# Collecting idna<4,>=2.5 (from requests->huggingface-hub<1.0,>=0.10.0->sample-factory)
#   Using cached idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->huggingface-hub<1.0,>=0.10.0->sample-factory)
#   Using cached urllib3-2.2.2-py3-none-any.whl.metadata (6.4 kB)
# Collecting certifi>=2017.4.17 (from requests->huggingface-hub<1.0,>=0.10.0->sample-factory)
#   Using cached certifi-2024.6.2-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./.conda/lib/python3.11/site-packages (from werkzeug>=1.0.1->tensorboard>=1.15.0->sample-factory) (2.1.5)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in ./.conda/lib/python3.11/site-packages (from sympy->torch!=1.13.0,<3.0,>=1.9->sample-factory) (1.3.0)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb>=0.12.9->sample-factory)
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Using cached sample_factory-2.1.1-py3-none-any.whl (9.0 MB)
# Using cached huggingface_hub-0.23.4-py3-none-any.whl (402 kB)
# Using cached numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
# Using cached signal_slot_mp-1.0.5-py3-none-any.whl (13 kB)
# Using cached tensorboard-2.17.0-py3-none-any.whl (5.5 MB)
# Using cached tensorboardX-2.6.2.2-py2.py3-none-any.whl (101 kB)
# Using cached threadpoolctl-3.5.0-py3-none-any.whl (18 kB)
# Using cached wandb-0.17.3-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.9 MB)
# Using cached colorlog-6.8.2-py3-none-any.whl (11 kB)
# Using cached opencv_python-4.10.0.84-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (62.5 MB)
# Using cached pyglet-2.0.15-py3-none-any.whl (884 kB)
# Using cached absl_py-2.1.0-py3-none-any.whl (133 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Using cached docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Using cached GitPython-3.1.43-py3-none-any.whl (207 kB)
# Using cached grpcio-1.64.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.6 MB)
# Using cached Markdown-3.6-py3-none-any.whl (105 kB)
# Using cached protobuf-4.25.3-cp37-abi3-manylinux2014_x86_64.whl (294 kB)
# Using cached PyYAML-6.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached sentry_sdk-2.7.1-py2.py3-none-any.whl (300 kB)
# Using cached tensorboard_data_server-0.7.2-py3-none-manylinux_2_31_x86_64.whl (6.6 MB)
# Using cached werkzeug-3.0.3-py3-none-any.whl (227 kB)
# Using cached setproctitle-1.3.3-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (31 kB)
# Using cached certifi-2024.6.2-py3-none-any.whl (164 kB)
# Using cached charset_normalizer-3.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (140 kB)
# Using cached Cython-3.0.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.6 MB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached idna-3.7-py3-none-any.whl (66 kB)
# Using cached urllib3-2.2.2-py3-none-any.whl (121 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Building wheels for collected packages: faster-fifo
#   Building wheel for faster-fifo (pyproject.toml) ... done
#   Created wheel for faster-fifo: filename=faster_fifo-1.4.7-cp311-cp311-linux_x86_64.whl size=87417 sha256=087469c07ca1453cfbf887eec282130bc024a50eae9b289bcbf6bdeb8bf419fe
#   Stored in directory: /home/mojitrk/.cache/pip/wheels/22/f5/17/f350858c6ed42cbe418e3f55f4de3749a32cf12c8ec415ba00
# Successfully built faster-fifo
# Installing collected packages: werkzeug, urllib3, threadpoolctl, tensorboard-data-server, smmap, setproctitle, pyyaml, pyglet, protobuf, numpy, markdown, idna, grpcio, docker-pycreds, cython, colorlog, click, charset-normalizer, certifi, absl-py, tensorboardx, tensorboard, sentry-sdk, requests, opencv-python, gitdb, faster-fifo, signal-slot-mp, huggingface-hub, gitpython, wandb, sample-factory
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.0
#     Uninstalling numpy-2.0.0:
#       Successfully uninstalled numpy-2.0.0
# Successfully installed absl-py-2.1.0 certifi-2024.6.2 charset-normalizer-3.3.2 click-8.1.7 colorlog-6.8.2 cython-3.0.10 docker-pycreds-0.4.0 faster-fifo-1.4.7 gitdb-4.0.11 gitpython-3.1.43 grpcio-1.64.1 huggingface-hub-0.23.4 idna-3.7 markdown-3.6 numpy-1.26.4 opencv-python-4.10.0.84 protobuf-4.25.3 pyglet-2.0.15 pyyaml-6.0.1 requests-2.32.3 sample-factory-2.1.1 sentry-sdk-2.7.1 setproctitle-1.3.3 signal-slot-mp-1.0.5 smmap-5.0.1 tensorboard-2.17.0 tensorboard-data-server-0.7.2 tensorboardx-2.6.2.2 threadpoolctl-3.5.0 urllib3-2.2.2 wandb-0.17.3 werkzeug-3.0.3
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
import vizdoom

if __name__ == '__main__':
    
    game = vizdoom.DoomGame()
    game.load_config('scenarios/basic.cfg')
    game.init()

    sample_actions = [
        [1, 0, 0],  
        [0, 1, 0],  
        [0, 0, 1],  
    ]

    n_episodes = 10
    current_episode = 0
    
    while current_episode < n_episodes:
        game.make_action(random.choice(sample_actions))

        if game.is_episode_finished():
            current_episode += 1
            game.new_episode()

    game.close()

# %%
import itertools as it
import os
import random
from collections import deque
from time import sleep, time

import numpy as np
import skimage.transform
import torch
import torch.nn as nn
import torch.optim as optim
from tqdm import trange

import vizdoom as vzd


# Q-learning settings
learning_rate = 0.00025
discount_factor = 0.99
train_epochs = 1
learning_steps_per_epoch = 2000
replay_memory_size = 10000

# NN learning settings
batch_size = 64

# Training regime
test_episodes_per_epoch = 100

# Other parameters
frame_repeat = 12
resolution = (30, 45)
episodes_to_watch = 10

model_savefile = "./model-doom.pth"
save_model = True
load_model = False
skip_learning = False

# Configuration file path
config_file_path = os.path.join(vzd.scenarios_path, "simpler_basic.cfg")
# config_file_path = os.path.join(vzd.scenarios_path, "rocket_basic.cfg")
# config_file_path = os.path.join(vzd.scenarios_path, "basic.cfg")

# Uses GPU if available
if torch.cuda.is_available():
    DEVICE = torch.device("cuda")
    torch.backends.cudnn.benchmark = True
else:
    DEVICE = torch.device("cpu")


def preprocess(img):
    """Down samples image to resolution"""
    img = skimage.transform.resize(img, resolution)
    img = img.astype(np.float32)
    img = np.expand_dims(img, axis=0)
    return img


def create_simple_game():
    print("Initializing doom...")
    game = vzd.DoomGame()
    game.load_config(config_file_path)
    game.set_window_visible(False)
    game.set_mode(vzd.Mode.PLAYER)
    game.set_screen_format(vzd.ScreenFormat.GRAY8)
    game.set_screen_resolution(vzd.ScreenResolution.RES_640X480)
    game.init()
    print("Doom initialized.")

    return game


def test(game, agent):
    """Runs a test_episodes_per_epoch episodes and prints the result"""
    print("\nTesting...")
    test_scores = []
    for test_episode in trange(test_episodes_per_epoch, leave=False):
        game.new_episode()
        while not game.is_episode_finished():
            state = preprocess(game.get_state().screen_buffer)
            best_action_index = agent.get_action(state)

            game.make_action(actions[best_action_index], frame_repeat)
        r = game.get_total_reward()
        test_scores.append(r)

    test_scores = np.array(test_scores)
    print(
        "Results: mean: {:.1f} +/- {:.1f},".format(
            test_scores.mean(), test_scores.std()
        ),
        "min: %.1f" % test_scores.min(),
        "max: %.1f" % test_scores.max(),
    )


def run(game, agent, actions, num_epochs, frame_repeat, steps_per_epoch=2000):
    """
    Run num epochs of training episodes.
    Skip frame_repeat number of frames after each action.
    """

    start_time = time()

    for epoch in range(num_epochs):
        game.new_episode()
        train_scores = []
        global_step = 0
        print(f"\nEpoch #{epoch + 1}")

        for _ in trange(steps_per_epoch, leave=False):
            state = preprocess(game.get_state().screen_buffer)
            action = agent.get_action(state)
            reward = game.make_action(actions[action], frame_repeat)
            done = game.is_episode_finished()

            if not done:
                next_state = preprocess(game.get_state().screen_buffer)
            else:
                next_state = np.zeros((1, 30, 45)).astype(np.float32)

            agent.append_memory(state, action, reward, next_state, done)

            if global_step > agent.batch_size:
                agent.train()

            if done:
                train_scores.append(game.get_total_reward())
                game.new_episode()

            global_step += 1

        agent.update_target_net()
        train_scores = np.array(train_scores)

        print(
            "Results: mean: {:.1f} +/- {:.1f},".format(
                train_scores.mean(), train_scores.std()
            ),
            "min: %.1f," % train_scores.min(),
            "max: %.1f," % train_scores.max(),
        )

        test(game, agent)
        if save_model:
            print("Saving the network weights to:", model_savefile)
            torch.save(agent.q_net, model_savefile)
        print("Total elapsed time: %.2f minutes" % ((time() - start_time) / 60.0))

    game.close()
    return agent, game


class DuelQNet(nn.Module):
    """
    This is Duel DQN architecture.
    see https://arxiv.org/abs/1511.06581 for more information.
    """

    def __init__(self, available_actions_count):
        super().__init__()
        self.conv1 = nn.Sequential(
            nn.Conv2d(1, 8, kernel_size=3, stride=2, bias=False),
            nn.BatchNorm2d(8),
            nn.ReLU(),
        )

        self.conv2 = nn.Sequential(
            nn.Conv2d(8, 8, kernel_size=3, stride=2, bias=False),
            nn.BatchNorm2d(8),
            nn.ReLU(),
        )

        self.conv3 = nn.Sequential(
            nn.Conv2d(8, 8, kernel_size=3, stride=1, bias=False),
            nn.BatchNorm2d(8),
            nn.ReLU(),
        )

        self.conv4 = nn.Sequential(
            nn.Conv2d(8, 16, kernel_size=3, stride=1, bias=False),
            nn.BatchNorm2d(16),
            nn.ReLU(),
        )

        self.state_fc = nn.Sequential(nn.Linear(96, 64), nn.ReLU(), nn.Linear(64, 1))

        self.advantage_fc = nn.Sequential(
            nn.Linear(96, 64), nn.ReLU(), nn.Linear(64, available_actions_count)
        )

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = x.view(-1, 192)
        x1 = x[:, :96]  # input for the net to calculate the state value
        x2 = x[:, 96:]  # relative advantage of actions in the state
        state_value = self.state_fc(x1).reshape(-1, 1)
        advantage_values = self.advantage_fc(x2)
        x = state_value + (
            advantage_values - advantage_values.mean(dim=1).reshape(-1, 1)
        )

        return x


class DQNAgent:
    def __init__(
        self,
        action_size,
        memory_size,
        batch_size,
        discount_factor,
        lr,
        load_model,
        epsilon=1,
        epsilon_decay=0.9996,
        epsilon_min=0.1,
    ):
        self.action_size = action_size
        self.epsilon = epsilon
        self.epsilon_decay = epsilon_decay
        self.epsilon_min = epsilon_min
        self.batch_size = batch_size
        self.discount = discount_factor
        self.lr = lr
        self.memory = deque(maxlen=memory_size)
        self.criterion = nn.MSELoss()

        if load_model:
            print("Loading model from: ", model_savefile)
            self.q_net = torch.load(model_savefile)
            self.target_net = torch.load(model_savefile)
            self.epsilon = self.epsilon_min

        else:
            print("Initializing new model")
            self.q_net = DuelQNet(action_size).to(DEVICE)
            self.target_net = DuelQNet(action_size).to(DEVICE)

        self.opt = optim.SGD(self.q_net.parameters(), lr=self.lr)

    def get_action(self, state):
        if np.random.uniform() < self.epsilon:
            return random.choice(range(self.action_size))
        else:
            state = np.expand_dims(state, axis=0)
            state = torch.from_numpy(state).float().to(DEVICE)
            action = torch.argmax(self.q_net(state)).item()
            return action

    def update_target_net(self):
        self.target_net.load_state_dict(self.q_net.state_dict())

    def append_memory(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    def train(self):
        batch = random.sample(self.memory, self.batch_size)
        batch = np.array(batch, dtype=object)

        states = np.stack(batch[:, 0]).astype(float)
        actions = batch[:, 1].astype(int)
        rewards = batch[:, 2].astype(float)
        next_states = np.stack(batch[:, 3]).astype(float)
        dones = batch[:, 4].astype(bool)
        not_dones = ~dones

        row_idx = np.arange(self.batch_size)  # used for indexing the batch

        # value of the next states with double q learning
        # see https://arxiv.org/abs/1509.06461 for more information on double q learning
        with torch.no_grad():
            next_states = torch.from_numpy(next_states).float().to(DEVICE)
            idx = row_idx, np.argmax(self.q_net(next_states).cpu().data.numpy(), 1)
            next_state_values = self.target_net(next_states).cpu().data.numpy()[idx]
            next_state_values = next_state_values[not_dones]

        # this defines y = r + discount * max_a q(s', a)
        q_targets = rewards.copy()
        q_targets[not_dones] += self.discount * next_state_values
        q_targets = torch.from_numpy(q_targets).float().to(DEVICE)

        # this selects only the q values of the actions taken
        idx = row_idx, actions
        states = torch.from_numpy(states).float().to(DEVICE)
        action_values = self.q_net(states)[idx].float().to(DEVICE)

        self.opt.zero_grad()
        td_error = self.criterion(q_targets, action_values)
        td_error.backward()
        self.opt.step()

        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay
        else:
            self.epsilon = self.epsilon_min


if __name__ == "__main__":
    # Initialize game and actions
    game = create_simple_game()
    n = game.get_available_buttons_size()
    actions = [list(a) for a in it.product([0, 1], repeat=n)]

    # Initialize our agent with the set parameters
    agent = DQNAgent(
        len(actions),
        lr=learning_rate,
        batch_size=batch_size,
        memory_size=replay_memory_size,
        discount_factor=discount_factor,
        load_model=load_model,
    )

    # Run the training for the set number of epochs
    if not skip_learning:
        agent, game = run(
            game,
            agent,
            actions,
            num_epochs=train_epochs,
            frame_repeat=frame_repeat,
            steps_per_epoch=learning_steps_per_epoch,
        )

        print("======================================")
        print("Training finished. It's time to watch!")

    # Reinitialize the game with window visible
    game.close()
    game.set_window_visible(True)
    game.set_mode(vzd.Mode.ASYNC_PLAYER)
    game.init()

    for _ in range(episodes_to_watch):
        game.new_episode()
        while not game.is_episode_finished():
            state = preprocess(game.get_state().screen_buffer)
            best_action_index = agent.get_action(state)

            # Instead of make_action(a, frame_repeat) in order to make the animation smooth
            game.set_action(actions[best_action_index])
            for _ in range(frame_repeat):
                game.advance_action()

        # Sleep between episodes
        sleep(1.0)
        score = game.get_total_reward()
        print("Total score: ", score)

# %%
game.set_window_visible(True)
game.set_mode(vzd.Mode.ASYNC_PLAYER)
game.init()

for _ in range(episodes_to_watch):
        game.new_episode()
        while not game.is_episode_finished():
            state = preprocess(game.get_state().screen_buffer)
            best_action_index = agent.get_action(state)

            game.set_action(actions[best_action_index])
            for _ in range(frame_repeat):
                game.advance_action()

        sleep(1.0)
        score = game.get_total_reward()
        print("Total score: ", score)
# Out:
# Total score:  0.0
# Total score:  0.0
# Total score:  0.0
# Total score:  0.0
# Total score:  0.0
# Total score:  0.0
# Total score:  0.0
# Total score:  0.0
# Total score:  0.0
# Total score:  0.0

# %%
#python -m sf_examples.vizdoom.enjoy_vizdoom --env=doom_battle --algo=APPO --experiment=doom_battle_w20_v20
